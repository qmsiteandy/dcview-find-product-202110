# %%
import requests
import time 
from bs4 import BeautifulSoup

#已通知過的商品ID紀錄，避免重複通知
usedID = []

#抓取DCview資料，搜尋對應商品，傳送訊息
def FindInDCview():
    print("FindInDCview:", time.ctime(time.time()))

    #----------Grab----------
    # 步驟一：
    result = requests.get("http://market.dcview.com/") #get 該網址的 HTML

    # 步驟二：
    soup = BeautifulSoup(result.text,"html.parser") #將網頁資料以 html.parser 解析器來解析
    #print(soup) #印出至畫面

    # 步驟三：
    datas = soup.find('table', 'table').tbody.find_all(class_="data-list-xs visible-xs")
    #print(datas)
    
    items = []

    for data in datas:
        #商品連結&ID0
        s_href = data.find('a').get('href')
        splitHref = s_href.split('/')
        s_id = splitHref[len(splitHref)-1]
        #徵或售
        s_mode = data.find(class_='btn-xs').text
        #縣市&品項名稱
        s_topic = data.find(class_='h5').text.strip()
        s_location = s_topic.split(']')[0].replace("[", "")
        s_name = s_topic.split(']')[1].strip()
        #價格
        s_price = data.find(class_='price').text.split()[0].replace(",", "")
        i_price = int(s_price)


        items.append({'id':s_id, 'mode':s_mode, 'location':s_location, 'name':s_name, 'price':i_price, 'href':s_href})
        
    #----------Compare----------    
    mode = '售'
    target_names = ['A73','A7iii','A7m4']
    budget = 38000
    locations = ['台北市','新北市']

    import re

    for item in items:

        #確認是否為出售
        if item['mode'] != mode: continue

        #搜尋名稱中是否有符合關鍵字
        for target_name in target_names:
            name_match = False
            if re.search(target_name, item['name'], re.IGNORECASE):
                name_match = True
                print(item['mode'], item['location'], item['name'], item['price'])
                msg = (item['mode'] +' ['+ item['location'] +']'+ item['name'] +' '+ str(item['price']) +'元 \n\n')
                break

        #此商品含所需關鍵字        
        if name_match:
            #確認此商品是否已通知過，避免重複通知
            b_used = False
            for used_id in usedID:
                if used_id == item['id']:
                    b_used = True
                    break
            if b_used == True: print('已通知過')
            else:    
                usedID.append(item['id'])
                #確認符合預算
                if(item['price'] <= budget): 
                    print('O符合預算/' + str(budget), end = ' ')
                    msg += 'O符合預算/'
                else: 
                    print('X超過預算/' + str(budget), end = ' ')
                    msg+= 'X超過預算/'
                #確認地區
                for location in locations:
                    location_match = False
                    if item['location'] == location: 
                        location_match = True
                        break
                if location_match: 
                    print('O地區符合')
                    msg+= 'O地區符合'
                else:
                    print('X地區不符合')
                    msg+= 'X地區不符合'
                #加上超連結
                msg += '\n-----------\n' + item['href']


                #傳送此商品資訊到LINE   
                SendLineMsg (msg)

# %%
def SendLineMsg (msg):     
    token = 'eXcB8Q9b6OT7fggGcOAE2UZzDwis3WSEBd7QOxCEXgF'   
    headers = {
            "Authorization": "Bearer " + token,
            "Content-Type": "application/x-www-form-urlencoded"
        }    
    params = {"message": msg}

    r = requests.post("https://notify-api.line.me/api/notify",
                      headers=headers, params=params)

# %%
import schedule  
import time  

schedule.every(5).minutes.at(":00").do(FindInDCview)  

while True:  
    schedule.run_pending()  
    time.sleep(10)
# Out:
# FindInDCview: Sun Oct 31 13:06:05 2021
# FindInDCview: Sun Oct 31 13:11:06 2021
# FindInDCview: Sun Oct 31 13:16:06 2021
# FindInDCview: Sun Oct 31 13:21:07 2021
# FindInDCview: Sun Oct 31 13:26:08 2021
# FindInDCview: Sun Oct 31 13:31:09 2021
# FindInDCview: Sun Oct 31 13:36:09 2021
# FindInDCview: Sun Oct 31 13:41:00 2021
# FindInDCview: Sun Oct 31 13:46:01 2021
# FindInDCview: Sun Oct 31 13:51:01 2021
# FindInDCview: Sun Oct 31 13:56:02 2021
# FindInDCview: Sun Oct 31 14:01:03 2021
# FindInDCview: Sun Oct 31 14:06:04 2021
# FindInDCview: Sun Oct 31 14:11:05 2021
# FindInDCview: Sun Oct 31 14:16:06 2021
# FindInDCview: Sun Oct 31 14:21:06 2021
# FindInDCview: Sun Oct 31 14:26:07 2021
# FindInDCview: Sun Oct 31 14:31:08 2021
# FindInDCview: Sun Oct 31 14:36:08 2021
# 售 台南市 SONY a73 a7m3 a7III 公司貨保固中 39000
# X超過預算/38000 X地區不符合
# FindInDCview: Sun Oct 31 14:41:09 2021
# 售 台南市 SONY a73 a7m3 a7III 公司貨保固中 39000
# 已通知過
# FindInDCview: Sun Oct 31 14:46:00 2021
# 售 台南市 SONY a73 a7m3 a7III 公司貨保固中 39000
# 已通知過
# FindInDCview: Sun Oct 31 14:51:01 2021
# 售 台南市 SONY a73 a7m3 a7III 公司貨保固中 39000
# 已通知過
# FindInDCview: Sun Oct 31 14:56:01 2021
# 售 台南市 SONY a73 a7m3 a7III 公司貨保固中 39000
# 已通知過
# FindInDCview: Sun Oct 31 15:01:02 2021
# 售 台南市 SONY a73 a7m3 a7III 公司貨保固中 39000
# 已通知過
# FindInDCview: Sun Oct 31 15:06:03 2021
# 售 台南市 SONY a73 a7m3 a7III 公司貨保固中 39000
# 已通知過
# FindInDCview: Sun Oct 31 15:11:04 2021
# 售 台南市 SONY a73 a7m3 a7III 公司貨保固中 39000
# 已通知過
# FindInDCview: Sun Oct 31 15:16:04 2021
# 售 台南市 SONY a73 a7m3 a7III 公司貨保固中 39000
# 已通知過
# FindInDCview: Sun Oct 31 15:21:05 2021
# 售 台南市 SONY a73 a7m3 a7III 公司貨保固中 39000
# 已通知過
# FindInDCview: Sun Oct 31 15:26:06 2021
# 售 台南市 SONY a73 a7m3 a7III 公司貨保固中 39000
# 已通知過
# FindInDCview: Sun Oct 31 15:31:06 2021
# 售 台南市 SONY a73 a7m3 a7III 公司貨保固中 39000
# 已通知過
# FindInDCview: Sun Oct 31 15:36:07 2021
# 售 台南市 SONY a73 a7m3 a7III 公司貨保固中 39000
# 已通知過
# FindInDCview: Sun Oct 31 15:41:08 2021
# 售 台南市 SONY a73 a7m3 a7III 公司貨保固中 39000
# 已通知過
# FindInDCview: Sun Oct 31 15:46:09 2021
# 售 台南市 SONY a73 a7m3 a7III 公司貨保固中 39000
# 已通知過
# FindInDCview: Sun Oct 31 15:51:09 2021
# 售 台南市 SONY a73 a7m3 a7III 公司貨保固中 39000
# 已通知過
# FindInDCview: Sun Oct 31 15:56:00 2021
# 售 台南市 SONY a73 a7m3 a7III 公司貨保固中 39000
# 已通知過
# FindInDCview: Sun Oct 31 16:01:01 2021
# 售 台南市 SONY a73 a7m3 a7III 公司貨保固中 39000
# 已通知過
# FindInDCview: Sun Oct 31 16:06:01 2021
# 售 台南市 SONY a73 a7m3 a7III 公司貨保固中 39000
# 已通知過
# FindInDCview: Sun Oct 31 16:11:02 2021
# 售 台南市 SONY a73 a7m3 a7III 公司貨保固中 39000
# 已通知過
# FindInDCview: Sun Oct 31 16:16:03 2021
# 售 台南市 SONY a73 a7m3 a7III 公司貨保固中 39000
# 已通知過
# FindInDCview: Sun Oct 31 16:21:04 2021
# 售 台南市 SONY a73 a7m3 a7III 公司貨保固中 39000
# 已通知過
# FindInDCview: Sun Oct 31 16:26:05 2021
# 售 台南市 SONY a73 a7m3 a7III 公司貨保固中 39000
# 已通知過
# FindInDCview: Sun Oct 31 16:31:05 2021
# 售 台南市 SONY a73 a7m3 a7III 公司貨保固中 39000
# 已通知過
# FindInDCview: Sun Oct 31 16:36:06 2021
# 售 台南市 SONY a73 a7m3 a7III 公司貨保固中 39000
# 已通知過
# FindInDCview: Sun Oct 31 16:41:07 2021
# 售 台南市 SONY a73 a7m3 a7III 公司貨保固中 39000
# 已通知過
# FindInDCview: Sun Oct 31 16:46:07 2021
# 售 台南市 SONY a73 a7m3 a7III 公司貨保固中 39000
# 已通知過
# FindInDCview: Sun Oct 31 16:51:08 2021
# 售 台南市 SONY a73 a7m3 a7III 公司貨保固中 39000
# 已通知過
# FindInDCview: Sun Oct 31 16:56:09 2021
# 售 台南市 SONY a73 a7m3 a7III 公司貨保固中 39000
# 已通知過
# FindInDCview: Sun Oct 31 17:01:00 2021
# 售 台南市 SONY a73 a7m3 a7III 公司貨保固中 39000
# 已通知過
# FindInDCview: Sun Oct 31 17:06:00 2021
# 售 台南市 SONY a73 a7m3 a7III 公司貨保固中 39000
# 已通知過
# FindInDCview: Sun Oct 31 17:11:01 2021
# 售 台南市 SONY a73 a7m3 a7III 公司貨保固中 39000
# 已通知過
# FindInDCview: Sun Oct 31 17:16:02 2021
# 售 台南市 SONY a73 a7m3 a7III 公司貨保固中 39000
# 已通知過
# FindInDCview: Sun Oct 31 17:21:03 2021
# 售 台南市 SONY a73 a7m3 a7III 公司貨保固中 39000
# 已通知過
# FindInDCview: Sun Oct 31 17:26:03 2021
# 售 台南市 SONY a73 a7m3 a7III 公司貨保固中 39000
# 已通知過
# FindInDCview: Sun Oct 31 17:31:04 2021
# 售 台南市 SONY a73 a7m3 a7III 公司貨保固中 39000
# 已通知過
# FindInDCview: Sun Oct 31 17:36:05 2021
# FindInDCview: Sun Oct 31 17:41:05 2021
# FindInDCview: Sun Oct 31 17:46:06 2021
# FindInDCview: Sun Oct 31 17:51:07 2021
# FindInDCview: Sun Oct 31 17:56:08 2021
# FindInDCview: Sun Oct 31 18:01:09 2021
# FindInDCview: Sun Oct 31 18:06:00 2021
# FindInDCview: Sun Oct 31 18:11:00 2021
# FindInDCview: Sun Oct 31 18:16:01 2021
# FindInDCview: Sun Oct 31 18:21:02 2021
# FindInDCview: Sun Oct 31 18:26:03 2021
# FindInDCview: Sun Oct 31 18:31:03 2021
# FindInDCview: Sun Oct 31 18:36:04 2021
# FindInDCview: Sun Oct 31 18:41:05 2021
# FindInDCview: Sun Oct 31 18:46:06 2021
# FindInDCview: Sun Oct 31 18:51:07 2021
# FindInDCview: Sun Oct 31 18:56:07 2021
# FindInDCview: Sun Oct 31 19:01:08 2021
# FindInDCview: Sun Oct 31 19:06:09 2021
# FindInDCview: Sun Oct 31 19:11:00 2021
# FindInDCview: Sun Oct 31 19:16:00 2021
# FindInDCview: Sun Oct 31 19:21:01 2021
# FindInDCview: Sun Oct 31 19:26:02 2021
# FindInDCview: Sun Oct 31 19:31:02 2021
# FindInDCview: Sun Oct 31 19:36:05 2021
# FindInDCview: Sun Oct 31 19:41:05 2021
# FindInDCview: Sun Oct 31 19:46:06 2021
# FindInDCview: Sun Oct 31 19:51:07 2021
# FindInDCview: Sun Oct 31 19:56:08 2021
# FindInDCview: Sun Oct 31 20:01:09 2021
# FindInDCview: Sun Oct 31 20:06:09 2021
# FindInDCview: Sun Oct 31 20:11:00 2021
# FindInDCview: Sun Oct 31 20:16:01 2021
# FindInDCview: Sun Oct 31 20:21:02 2021
# FindInDCview: Sun Oct 31 20:26:02 2021
# FindInDCview: Sun Oct 31 20:31:03 2021
# FindInDCview: Sun Oct 31 20:36:04 2021
# FindInDCview: Sun Oct 31 20:41:05 2021
# FindInDCview: Sun Oct 31 20:46:05 2021
# FindInDCview: Sun Oct 31 20:51:06 2021
# FindInDCview: Sun Oct 31 20:56:07 2021
# FindInDCview: Sun Oct 31 21:01:08 2021
# FindInDCview: Sun Oct 31 21:06:08 2021
# FindInDCview: Sun Oct 31 21:11:09 2021
# FindInDCview: Sun Oct 31 21:16:00 2021
# FindInDCview: Sun Oct 31 21:21:01 2021
# FindInDCview: Sun Oct 31 21:26:01 2021
# FindInDCview: Sun Oct 31 21:31:02 2021
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-fec809219521> in <module>
#       6 while True:
#       7     schedule.run_pending()
# ----> 8     time.sleep(10)
#
# KeyboardInterrupt:
